# %% [markdown]
# <hr style="height:2px;border:none" />
#
# # pydvma logger template
#
# *A template for using pydvma — the Python dynamics and vibration measurement and analysis package.*
#
# <hr style="height:2px;border:none" />

# %% [markdown]
# pydvma records data from a **soundcard** or from **National Instruments (NI) DAQ** hardware, and gives you tools to analyse and plot it (FFTs, transfer functions, sonograms, modal fits).
#
# This template imports the package as `ma`; the [online documentation](https://torebutlin.github.io/pydvma/) uses `dvma` — it is the same package, just a different alias. For installation see the [installation guide](https://torebutlin.github.io/pydvma/getting-started/installation/).

# %%
import pydvma as ma
import numpy as np

# %matplotlib widget
# If the interactive plots or the logger window don't appear, restart the
# kernel and use the Qt backend instead of the line above:
# %matplotlib qt

# %% [markdown]
# ### No hardware? Try some test data
#
# You can generate synthetic datasets to explore the analysis and plotting tools with nothing connected:

# %%
d = ma.create_test_impulse_data()   # synthetic impulse-response dataset
d.plot_time_data()

# %% [markdown]
# <hr style="height:2px;border:none" />
#
# ## Oscilloscope
#
# <hr style="height:2px;border:none" />
#
# Choose your acquisition settings:
#
# * `channels` — number of channels to record
# * `fs` — sampling rate in Hz
# * `chunk_size` — samples collected per update (sets the oscilloscope refresh rate)
# * `stored_time` — seconds of data to record
# * `viewed_time` — seconds of data shown on the oscilloscope
# * `device_driver` — `'soundcard'` (default audio path) or `'nidaq'` (National Instruments backend; see the cDAQ section below)
# * `device_index` — which device; `None` uses the system default (run `ma.list_available_devices()` to see the options)

# %%
settings = ma.MySettings(channels=1,
                         fs=44100,
                         chunk_size=200,
                         stored_time=2,
                         viewed_time=2,
                         device_driver='soundcard')
# device_driver='soundcard' is the default audio path.
# Use device_driver='nidaq' to select the National Instruments backend
# (any NI-DAQmx device) -- see the cDAQ example further down.

# %% [markdown]
# Now open a PC oscilloscope using your settings. This shows three plots:
#
# * the top one is like a normal oscilloscope showing the signal (toggle on/off with 'T');
# * the middle one shows the frequency spectrum of the signal (toggle on/off with 'F');
# * the bottom one shows the signal amplitudes (toggle on/off with 'L');
# * pause the display with 'P' (press again to resume streaming);
# * toggle whether the window is always on top with 'A'.
#
# Press the **space bar** to record data from the past `stored_time` seconds.
#
# * The first time you press it you will be prompted for where to save your data.
# * Subsequent presses auto-save to the same folder with a number added to the filename.
# * Press 's' to choose a new filename or location.
#
# **Pressing 'space' captures the *past* N seconds — so tap the beam, wait a second or so, then press space.**

# %%
osc = ma.Oscilloscope(settings)

# %% [markdown]
# <hr style="height:2px;border:none" />
#
# ## Logger GUI
#
# <hr style="height:2px;border:none" />
#
# You can also log data with the Logger GUI:

# %%
# COMMON SETTINGS EXAMPLE 1 (normal acquisition)
settings = ma.MySettings(channels=1,
                         fs=44100,
                         stored_time=2,
                         device_driver='soundcard')
logger1 = ma.Logger(settings,
                    test_name='ENTER_YOUR_TEST_NAME',
                    default_window='hann')

# %%
# COMMON SETTINGS EXAMPLE 2 (acquisition with pre-trigger)
settings = ma.MySettings(channels=2,
                         fs=3000,
                         stored_time=2,
                         pretrig_samples=100,
                         device_driver='soundcard',
                         device_index=None)   # None = system default; see ma.list_available_devices()
logger2 = ma.Logger(settings,
                    test_name='ENTER_YOUR_TEST_NAME',
                    default_window=None)

# %% [markdown]
# <hr style="height:2px;border:none" />
#
# ## National Instruments hardware (cDAQ example)
#
# <hr style="height:2px;border:none" />
#
# To use NI hardware set `device_driver='nidaq'`. This selects the NI-DAQmx backend and works for **any** National Instruments DAQ device the driver enumerates (USB-6003, USB-6212, a CompactDAQ chassis, …) — it is *not* for soundcards or non-NI hardware, and it needs the **NI-DAQmx driver** installed (Windows/Linux; not macOS).
#
# **Step 1 — see what is connected.** The `nidaq` list is indexed the way `device_index` expects (a cDAQ chassis appears as a single device):

# %%
ma.list_available_devices()

# %% [markdown]
# **Step 2 — let pydvma suggest safe settings** for the device at that index. `suggest_ni_settings` inspects the hardware and returns a dict of `MySettings` keyword arguments — voltage range, terminal mode (e.g. pseudo-differential for an NI 9234) and a valid sample rate — which you splat in with `**`:

# %%
# Replace 0 with the index of YOUR cDAQ from the list above.
base = ma.suggest_ni_settings(0)
base   # inspect the suggested device_driver / device_index / NI_mode / VmaxNI / fs ...

# %% [markdown]
# **Step 3 — build the settings**, adding your channel count and — for ICP/IEPE accelerometers on a 9234 — per-channel excitation and sensitivities. This example assumes a 4-channel 9234 with 100 mV/g accelerometers on `ai0`/`ai1`, a 2.3 mV/N force transducer on `ai2`, and `ai3` unused:
#
# * `iepe_excit_current_A` — 2 mA (`0.002`) **only** on the ICP channels; leave non-ICP inputs (the force transducer, loopbacks) at `0.0` — forcing current into them can damage them.
# * `channel_sensitivities` — volts per engineering unit (100 mV/g → `0.1`, 2.3 mV/N → `0.0023`); use `1.0` for "uncalibrated".
#
# To override anything `suggest_ni_settings` returned, merge it, e.g. `ma.MySettings(..., **{**base, 'fs': 12800})`.

# %%
settings = ma.MySettings(channels=4,
                         stored_time=2.0,
                         iepe_excit_current_A=[0.002, 0.002, 0.0, 0.0],
                         channel_sensitivities=[0.1, 0.1, 0.0023, 1.0],
                         **base)
logger_ni = ma.Logger(settings,
                      test_name='ENTER_YOUR_TEST_NAME',
                      default_window='hann')

# %% [markdown]
# <div class="alert alert-block alert-info">
#
# <b> Understanding the logger: </b><br/>
#
# When you press 'Save Dataset', the logger saves a &lt;DataSet&gt; object which has the following structure:
#
# <pre><code>
#     &lt;DataSet> class:
#           time_data_list: [&lt;TimeData>, &lt;TimeData>, &lt;TimeData>]
#           freq_data_list: [&lt;FreqData>, &lt;FreqData>, &lt;FreqData>]
#     cross_spec_data_list: []
#             tf_data_list: [&lt;TfData>, &lt;TfData>, &lt;TfData>]
#          modal_data_list: [&lt;ModalData>]
#           sono_data_list: []
#           meta_data_list: []
#
# </code></pre>
#
#
# Each type of data is arranged in 'sets', e.g. each measurement adds another &lt;TimeData&gt; set to time_data_list. This example has three sets of time, frequency and transfer-function data, and a &lt;ModalData&gt; set. Loading data also appends the loaded sets to the appropriate list.<br/><br/>
#
# <li> Press 'Calc FFT' and a &lt;FreqData&gt; item is calculated for each &lt;TimeData&gt; set.</li>
# <li> Press 'Calc TF' and a &lt;TfData&gt; item is calculated for each &lt;TimeData&gt; set.</li>
# <li> Press 'Calc TF average' and a single &lt;TfData&gt; item is calculated, averaging across all &lt;TimeData&gt; items (assuming they share the same settings).</li>
# </div>

# %% [markdown]
# <hr style="height:2px;border:none" />
#
# ## Command line tools
#
# <hr style="height:2px;border:none" />
#
# You can also log and analyse data directly from the command line (no GUI):

# %%
settings = ma.MySettings(channels=1,
                         fs=44100,
                         stored_time=2,
                         device_driver='soundcard')
d = ma.log_data(settings)

# %%
d.plot_time_data()

# %% [markdown]
# Calculate the FFT and transfer function, then plot them:

# %%
d.calculate_fft_set(window='hann')
d.calculate_tf_set(window='hann', N_frames=3)
d.plot_freq_data()
d.plot_tf_data()

# %% [markdown]
# Save or load a dataset:

# %%
ma.save_data(d)

# %%
d = ma.load_data()

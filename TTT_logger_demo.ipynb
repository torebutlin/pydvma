# %%
import matplotlib
import pydvma as ma

# %%
matplotlib.use('nbagg')

# %%
settings = ma.MySettings(fs=3000,
                        channels=1)

# %%
print(settings)
# Out:
# <MySettings class>
#
#                       fs: 3000
#                 channels: 1
#              stored_time: 2.0
#          pretrig_samples: None
#        pretrig_threshold: 0.05
#          pretrig_channel: 0
#          pretrig_timeout: 20.0
#            device_driver: soundcard
#             device_index: 1
#                output_fs: 3000
#          output_channels: 1
#     output_device_driver: soundcard
#      output_device_index: 6
#                   VmaxNI: 5.0
#               chunk_size: 100
#               num_chunks: 9
#              viewed_time: 0.3
#                    nbits: 16
#           init_view_time: True
#           init_view_freq: True
#         init_view_levels: True
#                   format: 8
#              device_name: None

# %%
d = ma.log_data(settings)
# Out:
# 1 Microphone Array (Realtek High
# Selected device: 1 : Microphone Array (Realtek High
# Logging data for 2.0 seconds.
#
# Logging data for 2.0 seconds.
# Logging complete.

# %%
print(d)
# Out:
# <DataSet> class:
#
#           time_data_list: [<TimeData>]
#           freq_data_list: []
#     cross_spec_data_list: []
#             tf_data_list: []
#          modal_data_list: []
#           sono_data_list: []
#           meta_data_list: []

# %%
d.plot_time_data()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
d.calculate_fft_set()

# %%
d.plot_freq_data()
# Out:
# <img src="data:image/png;base64,..." width="900">
